# %%
# Dependencies
import requests
import json
import pandas as pd

# Google developer API key
from config import gkey

# %%
# geocoordinates
target_city = "Denver"
target_search = "Chinese"
target_radius = 8000 
# in meters, about 5 miles


# set up a parameters dictionary
params = {
    "apikey": gkey,
    "q": target_city,
    "radius": target_radius,
    "cuisines": target_search,
}

# base url
base_url = "https://developers.zomato.com/api/v2.1/search"

# run a request using our params dictionary
response = requests.get(base_url, params=params)
gkey
# Out:
# 'f4188a23e764bfe4d12ed1e1b1ef9571'

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
print(response.url)
print('https://developers.zomato.com/api/v2.1/search?q=Denver&radius=8000&cuisines=Chinese')
# Out:
# https://developers.zomato.com/api/v2.1/search?apikey=f4188a23e764bfe4d12ed1e1b1ef9571&q=Denver&radius=8000&cuisines=Chinese
# https://developers.zomato.com/api/v2.1/search?q=Denver&radius=8000&cuisines=Chinese

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "restaurants": [
#         {
#             "restaurant": {
#                 "R": {
#                     "has_menu_status": {
#                         "delivery": -1,
#                         "takeaway": -1
#                     },
#                     "res_id": 16973752
#                 },
#                 "all_reviews": {
#                     "reviews": [
#                         {
#                             "review": {
#                                 "comments_count": 0,
#                                 "id": 28548147,
#                                 "likes": 0,
#                                 "rating": 2,
#                                 "rating_color": "FF7800",
#                                 "rating_text": "Blah!",
# ...

# %%
resp = requests.get(base_url, params).json()
# q = resp.get('restaurant').get("location").get("city")
target_search = resp.get("restaurants").get('cuisines')
name = resp.get("restaurants").get('name')
return{
    "Food_Type":target_search,
    "Restaurant":name
}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-1b3a632f2abc> in <module>
#       1 resp = requests.get(base_url, params).json()
#       2 # q = resp.get('restaurant').get("location").get("city")
# ----> 3 target_search = resp.get("restaurants").get('cuisines')
#       4 name = resp.get("restaurants").get('name')
#       5 return{
#
# AttributeError: 'list' object has no attribute 'get'

# %%
df = pd.DataFrame(places_data)
df = df[["q", "radius", "cuisines"]]


 "apikey": gkey,
    "q": target_city,
    "radius": target_radius,
    "cuisines": target_search,
}
print(len(df))
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-e9367c9999fb> in <module>
#       1 df = pd.DataFrame(places_data)
# ----> 2 df = df[["q", "radius", "cuisines"]]
#       3
#       4 print(len(df))
#       5 df.head()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# ...
